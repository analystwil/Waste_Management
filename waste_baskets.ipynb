# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Load in csv
waste_baskets_df = pd.read_csv("waste_baskets.csv")
waste_baskets_df
# Out:
#                                               the_geom  \
# 0    0101000020E610000059EEF6CDE7CA52C089AED36AB6FA...
# 1    0101000020E6100000727A5519B0CA52C03DFA98D8EAFA...
# 2    0101000020E6100000C42DF92A55C852C0FB842732E004...
# 3    0101000020E6100000FFC17C80AFCA52C0AB183BF8F1F9...
# 4    0101000020E6100000E521BA9179C952C03E91A9A244F9...
# ..                                                 ...
# 963  0101000020E6100000852B7B9696C952C04D333F68CC00...
# 964  0101000020E610000039FF2CEEA8D052C09FFEE7D2BDFC...
# 965  0101000020E6100000DBBC8FF3CBCE52C0F377CAD4E6FD...
# 966  0101000020E61000005874EA9AD0CA52C0EFB1B2FE97F9...
# 967  0101000020E610000095186ADED0CA52C04D653CF995F9...
#
#                                   the_geom_webmercator  objectid  serialnum  \
# 0    0101000020110F0000A993039DCEEB5FC1127A6054098A...       222     171945
# 1    0101000020110F00008FD2E5FD6FEB5FC1F06E0B6C438A...       223     171950
# ...

# %%
# Get the columns and the rows that are not null.
waste_baskets_df.count()
# Out:
# the_geom                968
# the_geom_webmercator    968
# objectid                968
# serialnum               968
# description             968
# recycler                968
# lat                     968
# lng                     968
# dtype: int64

# %%
# Get the data types of each column.
waste_baskets_df.dtypes
# Out:
# the_geom                 object
# the_geom_webmercator     object
# objectid                  int64
# serialnum                 int64
# description              object
# recycler                 object
# lat                     float64
# lng                     float64
# dtype: object

# %%
# Get the unique values of the recycler column.
waste_baskets_df["recycler"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Get the number of data points from the 'yes' recyclers.
yes_sum = sum(waste_baskets_df["recycler"]=="yes")

# %%
# Get the number of data points from the 'no' recyclers.
no_sum = sum(waste_baskets_df["recycler"]=="no")

# %%
waste_baskets_df.groupby(['recycler']).count()
# Out:
#           the_geom  the_geom_webmercator  objectid  serialnum  description  \
# recycler
# no             599                   599       599        599          599
# yes            369                   369       369        369          369
#
#           lat  lng
# recycler
# no        599  599
# yes       369  369
